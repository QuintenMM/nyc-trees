# %%
import pandas as pd
import numpy as np

# %%
#To open the csv file 
df = pd.read_csv('https://raw.githubusercontent.com/becodeorg/GNT-Arai-2.31/master/content/additional_resources/datasets/NYC%20trees/data_100000.csv?token=AUDYZY7NGDJ6SIZ7EW7PEELA43FFI')
# df = pd.read_csv('data_100000-Copy1.csv')
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#    created_at  tree_id  block_id  \
# 0  08/27/2015   180683    348711
# 1  09/03/2015   200540    315986
# 2  09/05/2015   204026    218365
# 3  09/05/2015   204337    217969
# 4  08/30/2015   189565    223043
#
#                                         the_geom  tree_dbh  stump_diam  \
# 0  POINT (-73.84421521958048 40.723091773924274)         3           0
# 1   POINT (-73.81867945834878 40.79411066708779)        21           0
# 2  POINT (-73.93660770459083 40.717580740099116)         3           0
# 3  POINT (-73.93445615919741 40.713537494833226)        10           0
# 4   POINT (-73.97597938483258 40.66677775537875)        21           0
#
#   curb_loc status health                           spc_latin  ... st_assem  \
# 0   OnCurb  Alive   Fair                         Acer rubrum  ...       28
# 1   OnCurb  Alive   Fair                   Quercus palustris  ...       27
# 2   OnCurb  Alive   Good  Gleditsia triacanthos var. inermis  ...       50
# ...

# %%
# delte missing values/blank spaces 

class clean_df():
    def __init__():
        pass
    def no_space(self,df) :
        return df.replace('^ | $', '', regex=True) 
    def no_empty_rows(self,df):
        return df.dropna(how='all')

# %%
df = df.applymap(lambda value: value.title() if type(value) == str else value)

# %%
df.rename(columns = {'tree_dbh':'tree_diam'}, inplace = True)

# %%
#no spaces: 
df.columns.tolist()
# Out:
# ['created_at',
#  'tree_id',
#  'block_id',
#  'the_geom',
#  'tree_diam',
#  'stump_diam',
#  'curb_loc',
#  'status',
#  'health',
#  'spc_latin',
#  'spc_common',
#  'steward',
#  'guards',
#  'sidewalk',
#  'user_type',
#  'problems',
#  'root_stone',
#  'root_grate',
#  'root_other',
#  'trnk_wire',
#  'trnk_light',
#  'trnk_other',
#  'brnch_ligh',
#  'brnch_shoe',
#  'brnch_othe',
#  'address',
#  'zipcode',
#  'zip_city',
#  'cb_num',
#  'borocode',
#  'boroname',
#  'cncldist',
#  'st_assem',
#  'st_senate',
#  'nta',
#  'nta_name',
#  'boro_ct',
#  'state',
#  'latitude',
#  'longitude',
#  'x_sp',
#  'y_sp']

# %%
pd.options.display.float_format = '{:.2f}'.format
df.head()
# Out:
#    created_at  tree_id  block_id  \
# 0  08/27/2015   180683    348711
# 1  09/03/2015   200540    315986
# 2  09/05/2015   204026    218365
# 3  09/05/2015   204337    217969
# 4  08/30/2015   189565    223043
#
#                                         the_geom  tree_diam  stump_diam  \
# 0  Point (-73.84421521958048 40.723091773924274)          3           0
# 1   Point (-73.81867945834878 40.79411066708779)         21           0
# 2  Point (-73.93660770459083 40.717580740099116)          3           0
# 3  Point (-73.93445615919741 40.713537494833226)         10           0
# 4   Point (-73.97597938483258 40.66677775537875)         21           0
#
#   curb_loc status health                           spc_latin  ... st_assem  \
# 0   Oncurb  Alive   Fair                         Acer Rubrum  ...       28
# 1   Oncurb  Alive   Fair                   Quercus Palustris  ...       27
# 2   Oncurb  Alive   Good  Gleditsia Triacanthos Var. Inermis  ...       50
# ...

# %%
# drop column with singele val 
df.drop(columns = df.columns[df.nunique() == 1],inplace = True)

# %%
df.columns.tolist()
# Out:
# ['created_at',
#  'tree_id',
#  'block_id',
#  'the_geom',
#  'tree_diam',
#  'stump_diam',
#  'curb_loc',
#  'status',
#  'health',
#  'spc_latin',
#  'spc_common',
#  'steward',
#  'guards',
#  'sidewalk',
#  'user_type',
#  'problems',
#  'root_stone',
#  'root_grate',
#  'root_other',
#  'trnk_wire',
#  'trnk_light',
#  'trnk_other',
#  'brnch_ligh',
#  'brnch_shoe',
#  'brnch_othe',
#  'address',
#  'zipcode',
#  'zip_city',
#  'cb_num',
#  'borocode',
#  'boroname',
#  'cncldist',
#  'st_assem',
#  'st_senate',
#  'nta',
#  'nta_name',
#  'boro_ct',
#  'latitude',
#  'longitude',
#  'x_sp',
#  'y_sp']

# %%
df.shape
# Out:
# (100000, 41)

# %%
#To get the exact rows where data is missing 
df[df['health'].isnull()]
# Out:
#        created_at  tree_id  block_id  \
# 630    08/31/2015   192569    302968
# 631    08/27/2015   179766    230466
# 634    08/27/2015   180619    348834
# 635    08/29/2015   184295    505610
# 636    09/08/2015   208828    107238
# ...           ...      ...       ...
# 99291  10/08/2015   296790    230356
# 99293  10/10/2015   303810    111012
# 99294  10/08/2015   297660    230365
# 99295  10/09/2015   303165    226311
# 99296  10/10/2015   306550    104059
#
#                                             the_geom  tree_diam  stump_diam  \
# 630     Point (-73.92155189169091 40.73804387948683)          2           0
# 631    Point (-73.95381354446748 40.637378972809216)          0          30
# 634     Point (-73.83937577603841 40.72529976652313)          0          10
# 635     Point (-73.88785030235013 40.85787584478919)          0           0
# 636     Point (-73.96085724372357 40.76491371354804)          0          15
# ...

# %%
# #Convert the columns to boolean data:  
change_to_boolean= ["root_stone", "root_grate", "root_other", "trunk_wire", "trnk_light", "trnk_other", "brch_light", "brch_shoe", "brch_other"]

# %%
#convert cat data.
cat_data = ['curb_loc', 'status', 'guards', 'sidewalk']
 
for column in cat_data:
    df[cat_data].astype('category')

# %%
df.to_csv('NYC-Trees', sep=',', encoding='utf-8')
